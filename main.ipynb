# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
events_df = pd.read_csv("data/events.csv")

# %%
events_df.head()
# Out:
#    Unnamed: 0  id        name         deadline_time  average_entry_score  \
# 0           0   1  Gameweek 1  2023-08-11T17:30:00Z                   64
# 1           1   2  Gameweek 2  2023-08-18T17:15:00Z                   44
# 2           2   3  Gameweek 3  2023-08-25T17:30:00Z                   44
# 3           3   4  Gameweek 4  2023-09-01T17:30:00Z                   72
# 4           4   5  Gameweek 5  2023-09-16T10:00:00Z                   44
#
#    finished  data_checked  highest_scoring_entry  deadline_time_epoch  \
# 0      True          True              3383750.0           1691775000
# 1      True          True              3338487.0           1692378900
# 2      True          True              9368956.0           1692984600
# 3      True          True              4354697.0           1693589400
# 4      True          True              6211182.0           1694858400
#
#    deadline_time_game_offset  ...  cup_leagues_created  \
# ...

# %%
events_df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'deadline_time', 'average_entry_score',
#        'finished', 'data_checked', 'highest_scoring_entry',
#        'deadline_time_epoch', 'deadline_time_game_offset', 'highest_score',
#        'is_previous', 'is_current', 'is_next', 'cup_leagues_created',
#        'h2h_ko_matches_created', 'chip_plays', 'most_selected',
#        'most_transferred_in', 'top_element', 'top_element_info',
#        'transfers_made', 'most_captained', 'most_vice_captained'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(12, 10))
sns.lineplot(data=events_df, x="id", y="highest_score")
plt.xticks(events_df["id"])
plt.xlabel("Game Week")
plt.ylabel("Highest Score")
# Out:
# Text(0, 0.5, 'Highest Score')

# %%
fig = plt.figure(figsize=(12, 10))
sns.lineplot(data=events_df, x="id", y="transfers_made")
plt.xticks(events_df["id"])
plt.xlabel("Game Week")
plt.ylabel("Transfers Made")
# Out:
# Text(0, 0.5, 'Transfers Made')

# %%
sns.scatterplot(data=events_df, x="transfers_made", y="highest_score")
# Out:
# <Axes: xlabel='transfers_made', ylabel='highest_score'>

# %%
events_df["most_selected"].value_counts()
# Out:
# most_selected
# 355.0    13
# Name: count, dtype: int64

# %%
events_df["most_captained"].value_counts()
# Out:
# most_captained
# 355.0    13
# Name: count, dtype: int64

# %%
events_df["most_vice_captained"].value_counts()
# Out:
# most_vice_captained
# 19.0     5
# 308.0    5
# 355.0    3
# Name: count, dtype: int64

# %%
players_df = pd.read_csv("data/players.csv")

# %%
players_df.head()
# Out:
#    Unnamed: 0  chance_of_playing_next_round  chance_of_playing_this_round  \
# 0           0                           0.0                           0.0
# 1           1                           NaN                           NaN
# 2           2                         100.0                         100.0
# 3           3                           0.0                           0.0
# 4           4                         100.0                         100.0
#
#      code  cost_change_event  cost_change_event_fall  cost_change_start  \
# 0  232223                  0                       0                 -1
# 1   58822                  0                       0                 -1
# 2  153256                  0                       0                 -1
# 3  438098                  0                       0                 -1
# 4  226597                  1                      -1                 -1
#
#    cost_change_start_fall  dreamteam_count  element_type  ...  now_cost_rank  \
# ...

# %%
players_df[players_df["status"] == "u"]
# Out:
#      Unnamed: 0  chance_of_playing_next_round  chance_of_playing_this_round  \
# 0             0                           0.0                           0.0
# 9             9                           0.0                           0.0
# 14           14                           0.0                           0.0
# 16           16                           0.0                           0.0
# 20           20                           0.0                           0.0
# ..          ...                           ...                           ...
# 719         719                           0.0                           0.0
# 722         722                           0.0                           0.0
# 724         724                           0.0                           0.0
# 734         734                           0.0                           0.0
# 737         737                           0.0                           0.0
#
# ...

# %%
players_df["status"].unique()
# Out:
# array(['u', 'a', 's', 'i', 'd', 'n'], dtype=object)

# %%
players_df[players_df["status"] == "u"]
# Out:
#      Unnamed: 0  chance_of_playing_next_round  chance_of_playing_this_round  \
# 0             0                           0.0                           0.0
# 9             9                           0.0                           0.0
# 14           14                           0.0                           0.0
# 16           16                           0.0                           0.0
# 20           20                           0.0                           0.0
# ..          ...                           ...                           ...
# 719         719                           0.0                           0.0
# 722         722                           0.0                           0.0
# 724         724                           0.0                           0.0
# 734         734                           0.0                           0.0
# 737         737                           0.0                           0.0
#
# ...

# %%
players_df.columns
# Out:
# Index(['Unnamed: 0', 'chance_of_playing_next_round',
#        'chance_of_playing_this_round', 'code', 'cost_change_event',
#        'cost_change_event_fall', 'cost_change_start', 'cost_change_start_fall',
#        'dreamteam_count', 'element_type', 'ep_next', 'ep_this', 'event_points',
#        'first_name', 'form', 'id', 'in_dreamteam', 'news', 'news_added',
#        'now_cost', 'photo', 'points_per_game', 'second_name',
#        'selected_by_percent', 'special', 'squad_number', 'status', 'team',
#        'team_code', 'total_points', 'transfers_in', 'transfers_in_event',
#        'transfers_out', 'transfers_out_event', 'value_form', 'value_season',
#        'web_name', 'minutes', 'goals_scored', 'assists', 'clean_sheets',
#        'goals_conceded', 'own_goals', 'penalties_saved', 'penalties_missed',
#        'yellow_cards', 'red_cards', 'saves', 'bonus', 'bps', 'influence',
#        'creativity', 'threat', 'ict_index', 'starts', 'expected_goals',
# ...
